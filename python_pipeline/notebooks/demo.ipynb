# %% [markdown]
# # SEEA-AI demoReproduces the multi-site accounts and figures used in the paper.

# %%
import sys; sys.path.insert(0,'../src')from seea_ai.run import mainrows, ai = main(['--backend','offline','--ai','numpy','--out','../results'])

# %% [markdown]
# ## Cross-site summary

# %%
import pandas as pdpd.read_csv('../results/accounts_summary.csv')[['site','cond_open','cond_close','dcond','dcarbon_tco2','dK_usd']]

# %% [markdown]
# ## AI condition model metrics

# %%
pd.read_csv('../results/ai_metrics.csv')

# %% [markdown]
# ## FiguresSee `results/figures/` — `<site>_<year>_raw.png` (true colour) and `_processed.png` (condition).For real Sentinel-2 imagery run with `--backend stac`.
